# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("trade.xlsx")
yıllar = pd.read_excel("yıllar.xlsx")

# %%
genel=pd.DataFrame(data)
yıllar=pd.DataFrame(yıllar)

# %%
genel = data.iloc[7:93]

# %%
genel.rename(columns={'Estimated Quarterly U.S. Retail Sales (Adjusted1): Total and E-commerce2' :'quarter'},inplace=True)
genel.rename(columns={'Unnamed: 3':'ecommerce'},inplace=True)
# Out:
# C:\Users\dogan\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
genel=genel.iloc[0:86][["quarter","ecommerce"]].reset_index()

# %%
genel['ecommerce']=genel['ecommerce'].apply(pd.to_numeric)

# %%
sonyıllar=genel.iloc[77:86]
sonyıllar
# Out:
#     index              quarter  ecommerce
# 77     84     1st quarter 2019     135629
# 78     85     2nd quarter 2019     141716
# 79     86     3rd quarter 2019     147965
# 80     87     4th quarter 2019     151218
# 81     88     1st quarter 2020     154575
# 82     89     2nd quarter 2020     203796
# 83     90     3rd quarter 2020     201382
# 84     91     4th quarter 2020     199665
# 85     92  1st quarter 2021(p)     215035

# %%
x = ['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']
plt.figure(figsize =[20,5])
plt.plot(x,yıllar['toplam'])
plt.grid()
plt.xlabel('years',family='times new roman', fontsize=25,color='black')
plt.ylabel('e-commerce',family='times new roman', fontsize=25, color='black')
# Out:
# Text(0, 0.5, 'e-commerce')

# %%
x = ['2019-1','2019-2','2019-3','2019-4','2020-1','2020-2','2020-3','2020-4','2021-1']
plt.figure(figsize =[20,5])
plt.plot(x,sonyıllar['ecommerce'])
plt.grid()
plt.xlabel('quarters', family='times new roman', fontsize=25,color='black')
plt.ylabel('e-commerce',family='times new roman', fontsize=25, color='black')
# Out:
# Text(0, 0.5, 'e-commerce')
